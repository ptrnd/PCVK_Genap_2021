# %% [markdown]
# <a href="https://colab.research.google.com/github/ptrnd/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('/content/drive/MyDrive/PCVK/gambar/j.png')

# %%
#3
kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a958550>,
#  <matplotlib.image.AxesImage at 0x7f2b9a8b3e50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#4
kernel = np.ones((5,5), np.uint8)
erode = cv.erode(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erode),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a8c2390>,
#  <matplotlib.image.AxesImage at 0x7f2b9a2e9f10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#5
kernel = kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a23ecd0>,
#  <matplotlib.image.AxesImage at 0x7f2b9a192610>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#6
kernel = kernel = np.ones((5,5), np.uint8)
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a192b10>,
#  <matplotlib.image.AxesImage at 0x7f2b9a0e6c10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a0f3150>,
#  <matplotlib.image.AxesImage at 0x7f2b9a037d50>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a046290>,
#  <matplotlib.image.AxesImage at 0x7f2b99f8ced0>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
#9 (SED = Cross 3)
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(3,3))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi'  )
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b99e381d0>,
#  <matplotlib.image.AxesImage at 0x7f2b99dbb390>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#9 (SED = Cross 5)
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(5,5))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi'  )
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9a912d10>,
#  <matplotlib.image.AxesImage at 0x7f2b9a179e90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#10 (SED = Circle 3)
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(3,3))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b99c2b810>,
#  <matplotlib.image.AxesImage at 0x7f2b99b7a4d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#10 (SED = Circle 5)
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b99afcc50>,
#  <matplotlib.image.AxesImage at 0x7f2b99acc5d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#11 (SED = Rectangle 3x5)
kernel = cv.getStructuringElement(cv.MORPH_RECT,(3,5))
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b998efe90>,
#  <matplotlib.image.AxesImage at 0x7f2b99848190>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#11 (SED = Rectangle 5x7)
kernel = cv.getStructuringElement(cv.MORPH_RECT,(5,7))
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b99848690>,
#  <matplotlib.image.AxesImage at 0x7f2b9978cb90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#11 (SED = Line 5)
kernel = cv.getStructuringElement(cv.MORPH_RECT, (1,5))
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2b9535cfd0>,
#  <matplotlib.image.AxesImage at 0x7f2b95331990>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#12
